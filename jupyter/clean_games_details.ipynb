# %%
import pandas as pd

# %%
df = pd.read_csv("resources/games_details.csv")
df.head()
# Out:
# /Users/mitch/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# ...

# %%
df.isnull().sum()
# Out:
# GAME_ID                   0
# TEAM_ID                   0
# TEAM_ABBREVIATION         0
# TEAM_CITY                 0
# PLAYER_ID                 0
# PLAYER_NAME               0
# NICKNAME             615591
# START_POSITION       412863
# COMMENT              558939
# MIN                  109690
# FGM                  109690
# FGA                  109690
# FG_PCT               109690
# FG3M                 109690
# FG3A                 109690
# FG3_PCT              109690
# FTM                  109690
# FTA                  109690
# FT_PCT               109690
# OREB                 109690
# DREB                 109690
# REB                  109690
# AST                  109690
# STL                  109690
# BLK                  109690
# TO                   109690
# PF                   109690
# PTS                  109690
# PLUS_MINUS           133351
# dtype: int64

# %%
wash = df.drop(["COMMENT", "START_POSITION", "TEAM_ABBREVIATION", "NICKNAME", "PLUS_MINUS", "TEAM_CITY", "OREB", "DREB", "PF"], axis=1)
wash
# Out:
#          GAME_ID     TEAM_ID  PLAYER_ID      PLAYER_NAME    MIN  FGM   FGA  \
# 0       22200477  1610612759    1629641   Romeo Langford  18:06  1.0   1.0
# 1       22200477  1610612759    1631110    Jeremy Sochan  31:01  7.0  14.0
# 2       22200477  1610612759    1627751     Jakob Poeltl  21:42  6.0   9.0
# 3       22200477  1610612759    1630170    Devin Vassell  30:20  4.0  13.0
# 4       22200477  1610612759    1630200        Tre Jones  27:44  7.0  12.0
# ...          ...         ...        ...              ...    ...  ...   ...
# 668623  11200005  1610612743     202706  Jordan Hamilton     19  4.0   9.0
# 668624  11200005  1610612743     202702   Kenneth Faried     23  7.0  11.0
# 668625  11200005  1610612743     201585     Kosta Koufos     15  3.0   7.0
# 668626  11200005  1610612743     202389   Timofey Mozgov     19  1.0   1.0
# 668627  11200005  1610612743     201951        Ty Lawson     27  3.0   6.0
#
# ...

# %%
wash.isnull().sum()
# Out:
# GAME_ID             0
# TEAM_ID             0
# PLAYER_ID           0
# PLAYER_NAME         0
# MIN            109690
# FGM            109690
# FGA            109690
# FG_PCT         109690
# FG3M           109690
# FG3A           109690
# FG3_PCT        109690
# FTM            109690
# FTA            109690
# FT_PCT         109690
# REB            109690
# AST            109690
# STL            109690
# BLK            109690
# TO             109690
# PTS            109690
# dtype: int64

# %%
scrub = wash.dropna()
scrub
# Out:
#          GAME_ID     TEAM_ID  PLAYER_ID      PLAYER_NAME    MIN  FGM   FGA  \
# 0       22200477  1610612759    1629641   Romeo Langford  18:06  1.0   1.0
# 1       22200477  1610612759    1631110    Jeremy Sochan  31:01  7.0  14.0
# 2       22200477  1610612759    1627751     Jakob Poeltl  21:42  6.0   9.0
# 3       22200477  1610612759    1630170    Devin Vassell  30:20  4.0  13.0
# 4       22200477  1610612759    1630200        Tre Jones  27:44  7.0  12.0
# ...          ...         ...        ...              ...    ...  ...   ...
# 668623  11200005  1610612743     202706  Jordan Hamilton     19  4.0   9.0
# 668624  11200005  1610612743     202702   Kenneth Faried     23  7.0  11.0
# 668625  11200005  1610612743     201585     Kosta Koufos     15  3.0   7.0
# 668626  11200005  1610612743     202389   Timofey Mozgov     19  1.0   1.0
# 668627  11200005  1610612743     201951        Ty Lawson     27  3.0   6.0
#
# ...

# %%
scrub.isnull().sum()
# Out:
# GAME_ID        0
# TEAM_ID        0
# PLAYER_ID      0
# PLAYER_NAME    0
# MIN            0
# FGM            0
# FGA            0
# FG_PCT         0
# FG3M           0
# FG3A           0
# FG3_PCT        0
# FTM            0
# FTA            0
# FT_PCT         0
# REB            0
# AST            0
# STL            0
# BLK            0
# TO             0
# PTS            0
# dtype: int64

# %%
scrub.to_csv("resources/clean_games_data.csv")
