# %%
import pandas as pd

# %%
mvp = pd.read_csv("./resources/mvp_votings.csv")
nba_df = pd.read_csv("./resources/nba_info.csv")
mvp["award_share"]
# Out:
# 0      0.658
# 1      0.613
# 2      0.414
# 3      0.261
# 4      0.120
#        ...
# 632    0.006
# 633    0.005
# 634    0.005
# 635    0.004
# 636    0.002
# Name: award_share, Length: 637, dtype: float64

# %%
mvp
# Out:
#      Unnamed: 0   fga  fg3a   fta   per  ts_pct  usg_pct  bpm   season  \
# 0             0  18.6   0.2   6.5  25.1   0.572     28.4  8.0  1980-81
# 1             1  18.3   0.9   4.0  19.9   0.528     24.3  5.1  1980-81
# 2             2  18.2   0.0   6.9  25.5   0.616     26.3  5.3  1980-81
# 3             3  19.3   0.0  10.1  25.1   0.585     27.6  3.7  1980-81
# 4             4  21.1   0.4   7.6  22.9   0.555     32.3  1.6  1980-81
# ..          ...   ...   ...   ...   ...     ...      ...  ...      ...
# 632         632  18.0   1.2   5.3  25.0   0.570     29.1  3.3  2017-18
# 633         633  15.6   3.4   7.2  23.7   0.590     24.9  5.0  2017-18
# 634         634  16.9   9.8   5.9  28.2   0.675     31.0  8.6  2017-18
# 635         635  16.8   3.4   7.4  22.9   0.573     33.4  2.6  2017-18
# 636         636  17.9   5.8   4.9  23.1   0.577     30.1  4.9  2017-18
#
#                   player  ...  pts_per_g  trb_per_g  ast_per_g  stl_per_g  \
# ...

# %%
mvp.columns
# Out:
# Index(['Unnamed: 0', 'fga', 'fg3a', 'fta', 'per', 'ts_pct', 'usg_pct', 'bpm',
#        'season', 'player', 'win_pct', 'votes_first', 'points_won',
#        'points_max', 'award_share', 'g', 'mp_per_g', 'pts_per_g', 'trb_per_g',
#        'ast_per_g', 'stl_per_g', 'blk_per_g', 'fg_pct', 'fg3_pct', 'ft_pct',
#        'ws', 'ws_per_48'],
#       dtype='object')

# %%
mvp_groupedII = mvp.groupby(["season", "player"]).mean()
mvp_groupedII.head()
# Out:
#                         Unnamed: 0   fga  fg3a  fta   per  ts_pct  usg_pct  \
# season  player
# 1980-81 Adrian Dantley        11.0  20.3   0.1  9.8  24.3   0.622     28.4
#         Artis Gilmore         21.0  10.0   0.0  6.5  21.7   0.699     18.5
#         Bernard King          13.0  15.4   0.1  5.4  19.9   0.617     23.2
#         Bob Lanier            22.0  10.7   0.0  4.1  19.7   0.573     21.8
#         Bobby Jones           26.0   9.3   0.0  4.3  20.1   0.604     20.8
#
#                         bpm   win_pct  votes_first  ...  pts_per_g  trb_per_g  \
# season  player                                      ...
# 1980-81 Adrian Dantley  4.6  0.341463          1.0  ...       30.7        6.4
#         Artis Gilmore   4.9  0.548780          0.0  ...       17.9       10.1
#         Bernard King    3.3  0.475610          0.0  ...       21.9        6.8
#         Bob Lanier      3.4  0.731707          0.0  ...       14.3        6.2
# ...

# %%
mvp_groupedII.columns
# Out:
# Index(['Unnamed: 0', 'fga', 'fg3a', 'fta', 'per', 'ts_pct', 'usg_pct', 'bpm',
#        'win_pct', 'votes_first', 'points_won', 'points_max', 'award_share',
#        'g', 'mp_per_g', 'pts_per_g', 'trb_per_g', 'ast_per_g', 'stl_per_g',
#        'blk_per_g', 'fg_pct', 'fg3_pct', 'ft_pct', 'ws', 'ws_per_48'],
#       dtype='object')

# %%
nba_df.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'SEASON',
#        'TEAM_ID_home', 'HOME_TEAM_WINS', 'TEAM_ID', 'CONFERENCE', 'TEAM',
#        'PLAYER_ID', 'PLAYER_NAME', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'REB', 'AST', 'STL', 'BLK',
#        'TO', 'PTS'],
#       dtype='object')

# %%
cleaning = nba_df.drop(columns=['HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'TEAM_ID_home', 'HOME_TEAM_WINS', 'TEAM_ID', 'CONFERENCE', 'TEAM'])
cleaning.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'SEASON', 'PLAYER_ID', 'PLAYER_NAME', 'MIN',
#        'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS'],
#       dtype='object')

# %%
NBA_grouped = cleaning.groupby(["SEASON", "PLAYER_NAME"]).mean()
NBA_grouped
# Out:
#                                  GAME_ID  PLAYER_ID        MIN       FGM  \
# SEASON     PLAYER_NAME
# 2003-01-01 A.J. Guyton      1.030000e+07     2062.0   5.000000  0.000000
#            Aaron McKie      2.016901e+07      243.0  27.473684  3.526316
#            Aaron Williams   2.280056e+07     1425.0  17.273810  2.273810
#            Ademola Okulaja  1.030000e+07     2144.0   5.000000  1.000000
#            Adonal Foyle     2.030088e+07     1502.0  12.590909  1.340909
# ...                                  ...        ...        ...       ...
# 2022-01-01 Zavier Simpson   1.220002e+07  1630285.0   7.500000  0.500000
#            Zeke Nnaji       2.027712e+07  1630192.0  10.461538  1.923077
#            Ziaire Williams  1.886695e+07  1630533.0  19.111111  2.222222
#            Zion Williamson  2.082091e+07  1629627.0  30.724138  8.862069
#            Zylan Cheatham   1.220004e+07  1629597.0   8.750000  0.750000
#
# ...

# %%
mvp_groupedII["award_share"]
# Out:
# season   player
# 1980-81  Adrian Dantley       0.022
#          Artis Gilmore        0.006
#          Bernard King         0.017
#          Bob Lanier           0.006
#          Bobby Jones          0.004
#                               ...
# 2017-18  LaMarcus Aldridge    0.006
#          LeBron James         0.731
#          Russell Westbrook    0.075
#          Stephen Curry        0.005
#          Victor Oladipo       0.002
# Name: award_share, Length: 637, dtype: float64
