# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../resources/mvp_votings.csv')
df.head()
# Out:
#    Unnamed: 0   fga  fg3a   fta   per  ts_pct  usg_pct  bpm   season  \
# 0           0  18.6   0.2   6.5  25.1   0.572     28.4  8.0  1980-81
# 1           1  18.3   0.9   4.0  19.9   0.528     24.3  5.1  1980-81
# 2           2  18.2   0.0   6.9  25.5   0.616     26.3  5.3  1980-81
# 3           3  19.3   0.0  10.1  25.1   0.585     27.6  3.7  1980-81
# 4           4  21.1   0.4   7.6  22.9   0.555     32.3  1.6  1980-81
#
#                 player  ...  pts_per_g  trb_per_g  ast_per_g  stl_per_g  \
# 0        Julius Erving  ...       24.6        8.0        4.4        2.1
# 1           Larry Bird  ...       21.2       10.9        5.5        2.0
# 2  Kareem Abdul-Jabbar  ...       26.2       10.3        3.4        0.7
# 3         Moses Malone  ...       27.8       14.8        1.8        1.0
# 4        George Gervin  ...       27.1        5.1        3.2        1.1
#
#    blk_per_g  fg_pct  fg3_pct  ft_pct    ws  ws_per_48
# 0        1.8   0.521    0.222   0.787  13.8      0.231
# ...

# %%
df.corr()
# Out:
#              Unnamed: 0       fga      fg3a       fta       per    ts_pct  \
# Unnamed: 0     1.000000  0.083607  0.538831  0.074387  0.331335  0.032944
# fga            0.083607  1.000000  0.261875  0.553790  0.497260 -0.149873
# fg3a           0.538831  0.261875  1.000000 -0.004625  0.176144  0.077008
# fta            0.074387  0.553790 -0.004625  1.000000  0.636986  0.280409
# per            0.331335  0.497260  0.176144  0.636986  1.000000  0.467495
# ts_pct         0.032944 -0.149873  0.077008  0.280409  0.467495  1.000000
# usg_pct        0.314805  0.879101  0.289759  0.671805  0.647622 -0.015948
# bpm            0.213720  0.230130  0.255947  0.361399  0.769631  0.349740
# win_pct        0.106472 -0.189876  0.028205 -0.134649  0.148810  0.223568
# votes_first    0.088636  0.225207  0.142075  0.200861  0.421488  0.167788
# points_won     0.167992  0.307073  0.161467  0.348106  0.591662  0.229535
# points_max     0.884143  0.060938  0.451345  0.068743  0.282893 -0.065490
# ...
