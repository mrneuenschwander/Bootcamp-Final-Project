# %%
import pandas as pd

# %%
df = pd.read_csv("player_stats.csv", index_col="RANK")
df.head()
# Out:
#                      FULL NAME TEAM  POS    AGE  GP   MPG  \
# RANK
# 1             Precious Achiuwa  Tor    F  22.74   6  27.8
# 2                 Steven Adams  Mem    C  28.91   7  16.2
# 3                  Bam Adebayo  Mia  C-F  24.92  18  34.1
# 4     Nickeil Alexander-Walker  Uta    G  23.79   1   4.7
# 5                Grayson Allen  Mil    G  26.69  12  25.4
#
#       MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# RANK
# 1                                                  57.8
# 2                                                  33.8
# 3                                                  71.0
# 4                                                   9.8
# 5                                                  53.0
#
#       USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# RANK
# 1                                                  18.2
# ...

# %%
df.dtypes
# Out:
# FULL NAME                                                                                                                                                                                                                     object
# TEAM                                                                                                                                                                                                                          object
# POS                                                                                                                                                                                                                           object
# AGE                                                                                                                                                                                                                          float64
# ...
